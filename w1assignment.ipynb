# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
cars=pd.read_csv('Cars.csv')
cars1=cars.copy()

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
cars.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
array1=cars.columns
array1
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
cars['name']=cars['name'].str.lower()
cars.set_index('name',inplace=True)
cars.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
cars['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
metric=cars['horsepower']/cars['weight']
cars['metric']=metric
cars.set_index('metric',inplace=True)
cars.head()
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# metric
# 0.037100  18.0          8         307.0       130.0    3504          12.0
# 0.044679  15.0          8         350.0       165.0    3693          11.5
# 0.043655  18.0          8         318.0       150.0    3436          11.0
# 0.043694  16.0          8         304.0       150.0    3433          12.0
# 0.040591  17.0          8         302.0       140.0    3449          10.5
#
#           model_year origin
# metric
# 0.037100          70    usa
# 0.044679          70    usa
# 0.043655          70    usa
# 0.043694          70    usa
# 0.040591          70    usa

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
cars1.head()
car_name=cars1[cars1['horsepower']==cars1['horsepower'].max()]['name']
car_name
# Out:
# 116    pontiac grand prix
# Name: name, dtype: object

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
cars_no=cars1[cars1['mpg']>=35].shape[0]
cars_no
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
most_cmn_origin=cars1[(cars1['horsepower']>100) & (cars1['weight']<3000)]['origin'].value_counts().idxmax()
most_cmn_origin
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
mean_acc=cars1[cars1['origin']=='japan']['acceleration'].mean()
mean_acc=round(mean_acc,2)
mean_acc
# Out:
# np.float64(16.17)

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
highest_avg_mpg=cars1.groupby('model_year')['mpg'].mean().idxmax()
highest_avg_mpg
# Out:
# np.int64(80)

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
median=cars1['mpg'].median()
best_car=cars1[cars1['mpg']>median]
best_car=best_car[best_car['horsepower']/best_car['weight']==best_car['horsepower']/best_car['weight'].max()]
best_car
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 364  26.6          8         350.0       105.0    3725          19.0
#
#      model_year origin                   name
# 364          81    usa  oldsmobile cutlass ls

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
avg_mpg_by_year_origin = cars1.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
sns.lineplot( data=avg_mpg_by_year_origin, x='model_year',  y='mpg',hue='origin',)
plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='origin')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
req_data=cars1[['horsepower','weight','origin','mpg']]
sns.scatterplot(data=req_data,x='horsepower',y='weight',hue='origin',size='mpg',hue_order=['japan', 'europe', 'usa'])
plt.title('Car Horsepower vs. Weight by Origin (MPG as Size)')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
no_of_cars=cars1.groupby('name')['model_year'].nunique()
multiple_cars=no_of_cars[no_of_cars>1]
std_mpg=cars1.groupby('name')['mpg'].std()
req_mpg=std_mpg[std_mpg<1]
req_cars=multiple_cars.index.intersection(req_mpg.index)
result=cars1[cars1['name'].isin(req_cars)]
result=result.groupby('name').agg({'mpg':'mean','model_year':'count'})
result
# Out:
#                                  mpg  model_year
# name
# amc matador (sw)           14.500000           2
# chevrolet chevelle malibu  17.500000           2
# datsun pl510               27.000000           2
# dodge aspen                18.850000           2
# ford galaxie 500           14.333333           3
# ford gran torino (sw)      13.500000           2
# ford ltd                   13.500000           2
# mazda 626                  31.450000           2
# plymouth fury iii          14.333333           3
# saab 99le                  24.500000           2
# toyota corolla 1200        31.500000           2
# toyota mark ii             19.500000           2
# volkswagen rabbit          29.250000           2

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
